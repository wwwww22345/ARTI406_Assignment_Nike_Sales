# %% [markdown]
# ARTI406 - Machine Learning
#
# # Assignment 1: Exploratory Data Analysis (EDA)
#
# EDA is the first and most important step in any Machine Learning project.
# Before building models, we must understand:
#
# - What does the data represent?
# - Are there missing values?
# - Are there outliers?
# - What patterns exist?
# - Which variables influence others?
#
# If we do not understand the data, we cannot build a good model.
#
# ### Why EDA is Important
#
# In real-world machine learning projects:
#
#     1- 70–80% of the time is spent on understanding and cleaning data
#     2- Only 20–30% is spent building models
#
# **EDA helps us:**
#
# - Detect errors
# - Identify trends
# - Discover relationships
# - Make business decisions

# %% [markdown]
# ![step1.png](attachment:step1.png)

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Make plots look cleaner
sns.set()

# %%
#print the path of the dataset
import kagglehub

path = kagglehub.dataset_download("nayakganesh007/nike-sales-uncleaned-dataset")
print("Path:", path)
# Out:
# Using Colab cache for faster access to the 'nike-sales-uncleaned-dataset' dataset.
# Path: /kaggle/input/nike-sales-uncleaned-dataset

# %%
# Load Dataset
df = pd.read_csv("/kaggle/input/nike-sales-uncleaned-dataset/Nike_Sales_Uncleaned.csv")

# Display first 5 rows. If you want to display all rows, use df.head(-1)
df.head(-1)
# Out:
#       Order_ID Gender_Category Product_Line      Product_Name Size  \
# 0         2000            Kids     Training       SuperRep Go    M
# 1         2001           Women       Soccer     Tiempo Legend    M
# 2         2002           Women       Soccer       Premier III    M
# 3         2003            Kids    Lifestyle        Blazer Mid    L
# 4         2004            Kids      Running    React Infinity   XL
# ...        ...             ...          ...               ...  ...
# 2494      4494           Women     Training  ZoomX Invincible    L
# 2495      4495            Kids   Basketball     Kyrie Flytrap   XL
# 2496      4496             Men   Basketball     Kyrie Flytrap    L
# 2497      4497             Men       Soccer     Tiempo Legend    7
# 2498      4498           Women     Training  ZoomX Invincible  NaN
#
#       Units_Sold      MRP  Discount_Applied  Revenue  Order_Date  \
# 0            NaN      NaN              0.47      0.0  2024-03-09
# 1            3.0  4957.93               NaN      0.0  2024-07-09
# 2            4.0      NaN               NaN      0.0         NaN
# 3            NaN  9673.57               NaN      0.0  04-10-2024
# 4            NaN      NaN               NaN      0.0  2024/09/12
# ...          ...      ...               ...      ...         ...
# 2494         NaN      NaN               NaN      0.0  12-02-2025
# 2495         3.0      NaN               NaN      0.0  2025-05-14
# 2496        -1.0      NaN               NaN      0.0         NaN
# 2497         NaN  6647.60              0.52      0.0  02-07-2025
# 2498         4.0  5358.70               NaN      0.0  11-12-2024
#
#      Sales_Channel     Region   Profit
# 0           Online  bengaluru  -770.45
# 1           Retail        Hyd  -112.53
# 2           Retail     Mumbai  3337.34
# 3           Online       Pune  3376.85
# 4           Retail      Delhi   187.89
# ...            ...        ...      ...
# 2494        Online    Kolkata  1357.29
# 2495        Online       Pune     2.97
# 2496        Online        Hyd  -487.36
# 2497        Retail  Bangalore  -918.14
# 2498        Online     Mumbai  3352.29
#
# [2499 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2500 non-null   int64
#  1   Gender_Category   2500 non-null   object
#  2   Product_Line      2500 non-null   object
#  3   Product_Name      2500 non-null   object
#  4   Size              1990 non-null   object
#  5   Units_Sold        1265 non-null   float64
#  6   MRP               1246 non-null   float64
#  7   Discount_Applied  832 non-null    float64
#  8   Revenue           2500 non-null   float64
#  9   Order_Date        1884 non-null   object
#  10  Sales_Channel     2500 non-null   object
#  11  Region            2500 non-null   object
#  12  Profit            2500 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 254.0+ KB

# %% [markdown]
# ### Check Missing Values

# %%
# Check all values
print(df.isna())
# Out:
#       Order_ID  Gender_Category  Product_Line  Product_Name   Size  \
# 0        False            False         False         False  False
# 1        False            False         False         False  False
# 2        False            False         False         False  False
# 3        False            False         False         False  False
# 4        False            False         False         False  False
# ...        ...              ...           ...           ...    ...
# 2495     False            False         False         False  False
# 2496     False            False         False         False  False
# 2497     False            False         False         False  False
# 2498     False            False         False         False   True
# 2499     False            False         False         False  False
#
#       Units_Sold    MRP  Discount_Applied  Revenue  Order_Date  Sales_Channel  \
# 0           True   True             False    False       False          False
# 1          False  False              True    False       False          False
# 2          False   True              True    False        True          False
# 3           True  False              True    False       False          False
# 4           True   True              True    False       False          False
# ...          ...    ...               ...      ...         ...            ...
# 2495       False   True              True    False       False          False
# 2496       False   True              True    False        True          False
# 2497        True  False             False    False       False          False
# 2498       False  False              True    False       False          False
# 2499        True  False              True    False       False          False
#
#       Region  Profit
# 0      False   False
# 1      False   False
# 2      False   False
# 3      False   False
# 4      False   False
# ...      ...     ...
# 2495   False   False
# 2496   False   False
# 2497   False   False
# 2498   False   False
# 2499   False   False
#
# [2500 rows x 13 columns]

# %% [markdown]
# # Check Missing Data

# %%
print(df.isna().sum())
# Out:
# Order_ID               0
# Gender_Category        0
# Product_Line           0
# Product_Name           0
# Size                 510
# Units_Sold          1235
# MRP                 1254
# Discount_Applied    1668
# Revenue                0
# Order_Date           616
# Sales_Channel          0
# Region                 0
# Profit                 0
# dtype: int64

# %% [markdown]
# # Check duplicate rows

# %%
# checking duplicate rows
df.duplicated()[df.duplicated()==True]
# Out:
# Series([], dtype: bool)

# %% [markdown]
# ### No. of rows and columns

# %%
#number of rows and columns

print("Shape (rows, columns): ", df.shape,"\n")

print("number of rows: ", df.shape[0])
print("number of columns: ", df.shape[1])
# Out:
# Shape (rows, columns):  (2500, 13)
#
# number of rows:  2500
# number of columns:  13

# %% [markdown]
# ### Data type of columns

# %%
# viewing the data types of columns
df.dtypes
# Out:
# Order_ID              int64
# Gender_Category      object
# Product_Line         object
# Product_Name         object
# Size                 object
# Units_Sold          float64
# MRP                 float64
# Discount_Applied    float64
# Revenue             float64
# Order_Date           object
# Sales_Channel        object
# Region               object
# Profit              float64
# dtype: object

# %% [markdown]
# # CLEANING FOR MISSING VALUES...

# %%
# Make a copy before cleaning
df_clean = df.copy()

# Drop rows where critical sales data is missing

# Units_Sold and MRP are essential for revenue calculation
df_clean = df_clean.dropna(subset=['Units_Sold', 'MRP'])

# Fill missing Discount_Applied with 0 (no discount)
df_clean['Discount_Applied'] = df_clean['Discount_Applied'].fillna(0)

# Fill missing Size with 'Not Specified'
df_clean['Size'] = df_clean['Size'].fillna('Not Specified')

#fix dataframe
df_clean['Order_Date'] = pd.to_datetime(df_clean['Order_Date'], dayfirst=True, errors='coerce')

## Fill missing Order_Date using mode (most common date)
df_clean['Order_Date'] = df_clean['Order_Date'].fillna(df_clean['Order_Date'].mode()[0])

#add features:
df_clean['Year'] = df_clean['Order_Date'].dt.year.astype(int)  # Convert to int, no NaN
df_clean['Month'] = df_clean['Order_Date'].dt.month
df_clean['Weekday'] = df_clean['Order_Date'].dt.day_name()

# Check remaining missing values
print("Missing values after cleaning:")
print(df_clean.isna().sum())
# Out:
# Missing values after cleaning:
# Order_ID            0
# Gender_Category     0
# Product_Line        0
# Product_Name        0
# Size                0
# Units_Sold          0
# MRP                 0
# Discount_Applied    0
# Revenue             0
# Order_Date          0
# Sales_Channel       0
# Region              0
# Profit              0
# Year                0
# Month               0
# Weekday             0
# dtype: int64

# %% [markdown]
# # Data after cleaning:

# %%
print(f"\n dataset: {df_clean.shape[0]} rows remaining")
df_clean.info()
df_clean.head(-1)
# Out:
#  dataset: 633 rows remaining
# <class 'pandas.core.frame.DataFrame'>
# Index: 633 entries, 1 to 2498
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          633 non-null    int64
#  1   Gender_Category   633 non-null    object
#  2   Product_Line      633 non-null    object
#  3   Product_Name      633 non-null    object
#  4   Size              633 non-null    object
#  5   Units_Sold        633 non-null    float64
#  6   MRP               633 non-null    float64
#  7   Discount_Applied  633 non-null    float64
#  8   Revenue           633 non-null    float64
#  9   Order_Date        633 non-null    datetime64[ns]
#  10  Sales_Channel     633 non-null    object
#  11  Region            633 non-null    object
#  12  Profit            633 non-null    float64
#  13  Year              633 non-null    int64
#  14  Month             633 non-null    int32
#  15  Weekday           633 non-null    object
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(7)
# memory usage: 81.6+ KB
#       Order_ID Gender_Category Product_Line   Product_Name           Size  \
# 1         2001           Women       Soccer  Tiempo Legend              M
# 5         2005           Women     Training   Flex Trainer              M
# 10        2010            Kids    Lifestyle     Waffle One              L
# 11        2011           Women     Training   Flex Trainer              L
# 16        2016           Women   Basketball     Air Jordan              M
# ...        ...             ...          ...            ...            ...
# 2463      4463             Men       Soccer    Premier III             11
# 2468      4468             Men       Soccer    Premier III             XL
# 2472      4472           Women   Basketball      LeBron 20  Not Specified
# 2478      4478           Women    Lifestyle    Air Force 1  Not Specified
# 2484      4484             Men   Basketball     Air Jordan             11
#
#       Units_Sold      MRP  Discount_Applied  Revenue Order_Date Sales_Channel  \
# 1            3.0  4957.93              0.00     0.00 2024-09-07        Retail
# 5            1.0  7363.96              0.00     0.00 2023-08-11        Retail
# 10           1.0  7949.83              0.00     0.00 2023-08-11        Online
# 11          -1.0  9586.08              0.00     0.00 2023-08-11        Retail
# 16           1.0  9871.75              0.30  6910.22 2023-08-11        Retail
# ...          ...      ...               ...      ...        ...           ...
# 2463         3.0  8317.53              0.60  9981.04 2023-08-11        Retail
# 2468         3.0  6077.13              1.13 -2370.08 2023-08-11        Online
# 2472         2.0  6833.94              0.00     0.00 2024-12-08        Online
# 2478         4.0  7748.38              0.00     0.00 2023-08-11        Retail
# 2484         3.0  5981.92              0.80  3589.15 2023-08-11        Retail
#
#         Region   Profit  Year  Month   Weekday
# 1          Hyd  -112.53  2024      9  Saturday
# 5        Delhi  1415.98  2023      8    Friday
# 10        Pune  1965.56  2023      8    Friday
# 11         Hyd  1667.08  2023      8    Friday
# 16    hyderbad  2452.69  2023      8    Friday
# ...        ...      ...   ...    ...       ...
# 2463      Pune  1821.65  2023      8    Friday
# 2468    Mumbai  3173.31  2023      8    Friday
# 2472       Hyd  -151.52  2024     12    Sunday
# 2478   Kolkata  3416.84  2023      8    Friday
# 2484  hyderbad  -751.05  2023      8    Friday
#
# [632 rows x 16 columns]

# %% [markdown]
# # BAD DATA BEFORE CLEANING...

# %%
# Convert Units_Sold to integer
df_clean['Units_Sold'] = df_clean['Units_Sold'].astype(int)

# Check negative and zero Units_Sold
print(f"Rows with negative or zero Units_Sold before: {(df_clean['Units_Sold'] <= 0).sum()}")

# Check discounts > 100%
print(f"Rows with discount >100% before: {(df_clean['Discount_Applied'] > 1.0).sum()}")

# Check negative or zero MRP
print(f"Rows with negative or zero MRP: {(df_clean['MRP'] <= 0).sum()}")

# Check negative revenue
print(f"Rows with negative or zero Revenue: {(df_clean['Revenue'] <= 0).sum()}")
# Out:
# Rows with negative or zero Units_Sold before: 213
# Rows with discount >100% before: 43
# Rows with negative or zero MRP: 0
# Rows with negative or zero Revenue: 520

# %% [markdown]
# # CLEANING DATA...

# %%
# This removes negative values (Zero units sold means a transaction with no products, represent data entry errors)
df_clean = df_clean[df_clean['Units_Sold'] > 0]


# Remove discounts > 100%
df_clean = df_clean[df_clean['Discount_Applied'] <= 1.0]

# Remove bad Revenue
df_clean = df_clean[df_clean['Revenue'] > 0]

print(f"\n Final clean dataset: {df_clean.shape[0]} rows remaining")
# Out:
#  Final clean dataset: 110 rows remaining

# %% [markdown]
# # Data after cleaning

# %%
print(f"\n dataset: {df_clean.shape[0]} rows remaining")
df_clean.info()
df_clean.head(-1)
# Out:
#  dataset: 110 rows remaining
# <class 'pandas.core.frame.DataFrame'>
# Index: 110 entries, 16 to 2484
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          110 non-null    int64
#  1   Gender_Category   110 non-null    object
#  2   Product_Line      110 non-null    object
#  3   Product_Name      110 non-null    object
#  4   Size              110 non-null    object
#  5   Units_Sold        110 non-null    int64
#  6   MRP               110 non-null    float64
#  7   Discount_Applied  110 non-null    float64
#  8   Revenue           110 non-null    float64
#  9   Order_Date        110 non-null    datetime64[ns]
#  10  Sales_Channel     110 non-null    object
#  11  Region            110 non-null    object
#  12  Profit            110 non-null    float64
#  13  Year              110 non-null    int64
#  14  Month             110 non-null    int32
#  15  Weekday           110 non-null    object
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(3), object(7)
# memory usage: 14.2+ KB
#       Order_ID Gender_Category Product_Line        Product_Name  \
# 16        2016           Women   Basketball          Air Jordan
# 31        2031             Men       Soccer         Premier III
# 57        2048             Men    Lifestyle          Waffle One
# 63        2063           Women   Basketball          Air Jordan
# 71        2071            Kids    Lifestyle          Blazer Mid
# ...        ...             ...          ...                 ...
# 2400      4400           Women    Lifestyle         Air Force 1
# 2418      4418           Women     Training            Metcon 7
# 2445      4445           Women     Training            Metcon 7
# 2446      4446             Men       Soccer  Mercurial Superfly
# 2463      4463             Men       Soccer         Premier III
#
#                Size  Units_Sold      MRP  Discount_Applied   Revenue  \
# 16                M           1  9871.75              0.30   6910.22
# 31    Not Specified           4  3493.04              0.82   2514.99
# 57                M           3  6216.29              0.94   1118.93
# 63                M           1  9751.00              0.16   8190.84
# 71                M           3  7849.81              0.49  12010.21
# ...             ...         ...      ...               ...       ...
# 2400              M           4  7798.57              0.28  22459.88
# 2418             XL           2  3139.93              0.46   3391.12
# 2445             XL           1  5915.27              0.12   5205.44
# 2446              M           2  3469.31              0.28   4995.81
# 2463             11           3  8317.53              0.60   9981.04
#
#      Order_Date Sales_Channel    Region   Profit  Year  Month   Weekday
# 16   2023-08-11        Retail  hyderbad  2452.69  2023      8    Friday
# 31   2024-09-05        Online     Delhi   350.70  2024      9  Thursday
# 57   2023-08-11        Online    Mumbai  -642.02  2023      8    Friday
# 63   2023-08-11        Retail      Pune  1130.31  2023      8    Friday
# 71   2023-08-11        Retail      Pune  -882.96  2023      8    Friday
# ...         ...           ...       ...      ...   ...    ...       ...
# 2400 2023-08-11        Retail   Kolkata  1334.40  2023      8    Friday
# 2418 2023-08-11        Online   Kolkata  3548.13  2023      8    Friday
# 2445 2023-08-11        Retail    Mumbai  3456.95  2023      8    Friday
# 2446 2023-08-11        Retail      Pune  2671.58  2023      8    Friday
# 2463 2023-08-11        Retail      Pune  1821.65  2023      8    Friday
#
# [109 rows x 16 columns]

# %%
df_clean.head(-1)
# Out:
#       Order_ID Gender_Category Product_Line        Product_Name  \
# 16        2016           Women   Basketball          Air Jordan
# 31        2031             Men       Soccer         Premier III
# 57        2048             Men    Lifestyle          Waffle One
# 63        2063           Women   Basketball          Air Jordan
# 71        2071            Kids    Lifestyle          Blazer Mid
# ...        ...             ...          ...                 ...
# 2400      4400           Women    Lifestyle         Air Force 1
# 2418      4418           Women     Training            Metcon 7
# 2445      4445           Women     Training            Metcon 7
# 2446      4446             Men       Soccer  Mercurial Superfly
# 2463      4463             Men       Soccer         Premier III
#
#                Size  Units_Sold      MRP  Discount_Applied   Revenue  \
# 16                M           1  9871.75              0.30   6910.22
# 31    Not Specified           4  3493.04              0.82   2514.99
# 57                M           3  6216.29              0.94   1118.93
# 63                M           1  9751.00              0.16   8190.84
# 71                M           3  7849.81              0.49  12010.21
# ...             ...         ...      ...               ...       ...
# 2400              M           4  7798.57              0.28  22459.88
# 2418             XL           2  3139.93              0.46   3391.12
# 2445             XL           1  5915.27              0.12   5205.44
# 2446              M           2  3469.31              0.28   4995.81
# 2463             11           3  8317.53              0.60   9981.04
#
#      Order_Date Sales_Channel    Region   Profit  Year  Month   Weekday
# 16   2023-08-11        Retail  hyderbad  2452.69  2023      8    Friday
# 31   2024-09-05        Online     Delhi   350.70  2024      9  Thursday
# 57   2023-08-11        Online    Mumbai  -642.02  2023      8    Friday
# 63   2023-08-11        Retail      Pune  1130.31  2023      8    Friday
# 71   2023-08-11        Retail      Pune  -882.96  2023      8    Friday
# ...         ...           ...       ...      ...   ...    ...       ...
# 2400 2023-08-11        Retail   Kolkata  1334.40  2023      8    Friday
# 2418 2023-08-11        Online   Kolkata  3548.13  2023      8    Friday
# 2445 2023-08-11        Retail    Mumbai  3456.95  2023      8    Friday
# 2446 2023-08-11        Retail      Pune  2671.58  2023      8    Friday
# 2463 2023-08-11        Retail      Pune  1821.65  2023      8    Friday
#
# [109 rows x 16 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110 entries, 16 to 2484
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          110 non-null    int64
#  1   Gender_Category   110 non-null    object
#  2   Product_Line      110 non-null    object
#  3   Product_Name      110 non-null    object
#  4   Size              110 non-null    object
#  5   Units_Sold        110 non-null    int64
#  6   MRP               110 non-null    float64
#  7   Discount_Applied  110 non-null    float64
#  8   Revenue           110 non-null    float64
#  9   Order_Date        110 non-null    datetime64[ns]
#  10  Sales_Channel     110 non-null    object
#  11  Region            110 non-null    object
#  12  Profit            110 non-null    float64
#  13  Year              110 non-null    int64
#  14  Month             110 non-null    int32
#  15  Weekday           110 non-null    object
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(3), object(7)
# memory usage: 14.2+ KB

# %%
# Statistical summary
df_clean.describe(include='all')
# Out:
#            Order_ID Gender_Category Product_Line  Product_Name           Size  \
# count    110.000000             110          110           110            110
# unique          NaN               3            5            20             11
# top             NaN             Men     Training  Flex Trainer  Not Specified
# freq            NaN              41           29            11             27
# mean    3183.109091             NaN          NaN           NaN            NaN
# min     2003.000000             NaN          NaN           NaN            NaN
# 25%     2538.750000             NaN          NaN           NaN            NaN
# 50%     3171.000000             NaN          NaN           NaN            NaN
# 75%     3793.250000             NaN          NaN           NaN            NaN
# max     4484.000000             NaN          NaN           NaN            NaN
# std      742.921055             NaN          NaN           NaN            NaN
#
#         Units_Sold          MRP  Discount_Applied       Revenue  \
# count   110.000000   110.000000        110.000000    110.000000
# unique         NaN          NaN               NaN           NaN
# top            NaN          NaN               NaN           NaN
# freq           NaN          NaN               NaN           NaN
# mean      2.390909  5998.959273          0.457273   7284.846909
# min       1.000000  2068.950000          0.010000    236.320000
# 25%       1.250000  4201.837500          0.230000   3305.942500
# 50%       2.000000  6170.740000          0.455000   5591.790000
# 75%       3.000000  7837.000000          0.677500   9235.067500
# max       4.000000  9872.380000          0.980000  37169.350000
# std       1.075972  2256.650952          0.279557   6177.402639
#
#                            Order_Date Sales_Channel  Region       Profit  \
# count                             110           110     110   110.000000
# unique                            NaN             2       9          NaN
# top                               NaN        Retail  Mumbai          NaN
# freq                              NaN            57      21          NaN
# mean    2023-08-28 10:15:16.363636480           NaN     NaN  1274.430364
# min               2023-03-09 00:00:00           NaN     NaN -1152.860000
# 25%               2023-08-11 00:00:00           NaN     NaN    54.315000
# 50%               2023-08-11 00:00:00           NaN     NaN  1311.880000
# 75%               2023-08-11 00:00:00           NaN     NaN  2569.942500
# max               2025-03-01 00:00:00           NaN     NaN  3894.950000
# std                               NaN           NaN     NaN  1495.253704
#
#                Year       Month Weekday
# count    110.000000  110.000000     110
# unique          NaN         NaN       6
# top             NaN         NaN  Friday
# freq            NaN         NaN     101
# mean    2023.063636    7.818182     NaN
# min     2023.000000    3.000000     NaN
# 25%     2023.000000    8.000000     NaN
# 50%     2023.000000    8.000000     NaN
# 75%     2023.000000    8.000000     NaN
# max     2025.000000    9.000000     NaN
# std        0.280147    0.910508     NaN

# %% [markdown]
# ### Descriptive summary Statistics

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ##Revenue Distribution

# %%
plt.hist(df_clean['Revenue'], bins=20, color='skyblue')
plt.title('Distribution of Revenue per Transaction', fontsize=12, fontweight='bold')
plt.xlabel('Revenue ($)')
plt.ylabel('Number of Transactions')
plt.axvline(df_clean['Revenue'].mean(), color='red', linestyle='--', label=f'Mean: ${df_clean["Revenue"].mean():.0f}')
plt.show()

# %% [markdown]
# Most transactions fall in the range of 5000- 10000, with fewer high-value sales above 20000. The distribution is right-skewed, showing normal sales are mid range, not very low or very high

# %% [markdown]
# ##Units Distribution

# %%
plt.hist(df_clean['Units_Sold'], color='lightgreen')
plt.title('Distribution of Units Sold per Transaction', fontsize=12, fontweight='bold')
plt.xlabel('Units Sold')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Most transactions have 1-4 units per order, with 2 units being most common. showing customers typically buy 2-3 items per transaction.

# %% [markdown]
# ##Gender Revenue

# %%
gender_revenue = df_clean.groupby('Gender_Category')['Revenue'].sum()
colors = ['skyblue', 'lightgreen', 'pink']
plt.pie(gender_revenue, labels=gender_revenue.index, autopct='%1.1f%%',
        colors=colors, startangle=90)
plt.title('Revenue Distribution by Gender', fontsize=12, fontweight='bold')
gender_revenue
# Out:
# Gender_Category
# Kids     228266.29
# Men      310701.44
# Women    262365.43
# Name: Revenue, dtype: float64

# %% [markdown]
# Men generate the highest revenue at 38.8% , followed closely by Women at 32.7% , and Kids at 28.5% .The distribution is balanced across the three categories

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ##Product Line Revenue

# %%
product_revenue = df_clean.groupby('Product_Line')['Revenue'].sum().sort_values()
product_revenue.plot(kind='barh', color='pink')
plt.title('Total Revenue by Product Line', fontsize=12, fontweight='bold')
plt.xlabel('Total Revenue ($)')
plt.ylabel('Product Line')
product_revenue
# Out:
# Product_Line
# Running        94609.75
# Soccer        147298.39
# Basketball    168381.68
# Lifestyle     179814.05
# Training      211229.29
# Name: Revenue, dtype: float64

# %% [markdown]
# Training generates the highest revenue at 211,229, and Running contribute the least at 94,610.
# Training products are the top performer

# %% [markdown]
# ##Discount vs Revenue

# %%
plt.scatter(df_clean['Discount_Applied'] * 100, df_clean['Revenue'],
            alpha=0.6, color='green')
plt.title('Discount Percentage vs Revenue', fontsize=12, fontweight='bold')
plt.xlabel('Discount (%)')
plt.ylabel('Revenue ($)')
plt.grid(True, alpha=0.3)

# %% [markdown]
# The scatter plot shows No clear relationship between discount and revenue. discounts alone don't determine sales performance.
# heavily discounted transactions generate low revenue, while full priced product get higher revenue.

# %% [markdown]
# ##Sales Channel

# %%
channel_revenue = df_clean.groupby('Sales_Channel')['Revenue'].sum()
plt.pie(channel_revenue, labels=channel_revenue.index, autopct='%1.1f%%',
        colors=['skyblue','lightgreen'] , startangle=90)
plt.title('Revenue by Sales Channel', fontsize=12, fontweight='bold')
channel_revenue
# Out:
# Sales_Channel
# Online    414364.49
# Retail    386968.67
# Name: Revenue, dtype: float64

# %% [markdown]
# Online generates slightly higher revenuecompared to Retail.
# Nike's sales are well-balanced across digital and physical stores.

# %% [markdown]
# ##Top Products

# %%
top_products = df_clean.groupby('Product_Name')['Revenue'].sum().nlargest(5)
top_products.plot(kind='bar', color='pink')
plt.title('Top 5 Products by Revenue', fontsize=12, fontweight='bold')
plt.xlabel('Product Name')
plt.ylabel('Total Revenue ($)')
plt.xticks(rotation=45, ha='right')
top_products
# Out:
# Product_Name
# Flex Trainer    77067.95
# LeBron 20       63676.17
# Air Zoom        58144.30
# Waffle One      56154.20
# Zoom Freak      51500.51
# Name: Revenue, dtype: float64

# %% [markdown]
# Flex Trainer best selling product in revenue, and Zoom Freak contribute the least. indicating clear product performance differences. Training shoes leading the revenue

# %% [markdown]
# ## Revenue by Region

# %%
region_revenue = df_clean.groupby('Region')['Revenue'].sum().sort_values()
plt.barh(region_revenue.index, region_revenue.values, color='lightgreen')
plt.title('Revenue by Region')
plt.xlabel('Total Revenue ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Kolkata generates the highest revenue, followed by Delhi and Pune. Performance varies significantly across cities

# %% [markdown]
# # Time-Based Analysis

# %% [markdown]
# ##Monthly Trend

# %%
monthly_revenue = df_clean.groupby('Month')['Revenue'].sum()
plt.plot(monthly_revenue.index, monthly_revenue.values, marker='o')
plt.title('Monthly Revenue Trend', fontsize=12, fontweight='bold')
plt.xlabel('Month')
plt.ylabel('Total Revenue ($)')
plt.xticks(range(1, 13))
plt.grid(True, alpha=0.3)
monthly_revenue
# Out:
# Month
# 3     15613.45
# 4      7127.85
# 7      2839.18
# 8    773237.69
# 9      2514.99
# Name: Revenue, dtype: float64

# %% [markdown]
# August shows massive revenue spike at 773,238 , while all other months have minimal sales under 16,000. This could indicate a back to school or summer promotion period. The remaining months show very low activity.

# %% [markdown]
# ##Correlation Matrix

# %%
# Select numeric columns
numeric_cols = ['Units_Sold', 'MRP', 'Discount_Applied', 'Revenue', 'Profit']

# Create correlation matrix
corr_matrix = df_clean[numeric_cols].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f')
plt.title('Correlation Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insights from correlation matrix:
#
# close to +1 = strong positive relationship
#
# close to -1 = strong negative relationship
#
# close to 0 = no relationship

# %% [markdown]
# # Assignment
#
# In this assignment, you will apply the EDA techniques learned in class to a dataset of your choice. You must submit the following to the assignment 1 folder.
# 1. Dataset file
# 2. Dataset Description readme file
# 2. Jupyter Notebook
